# %% [markdown]
# # Naive Baseline Methods

# %% [markdown]
# ## Continuous Naive Bayesian Classifier

# %%
from baseline_methods.continuous_naive_Bayesian_classifier import *

# classifier = empty_continuous_Bayesian_classifier()

# classifier = file_to_continuous_Bayesian_classifier("continuous_Bayesian_classifier.txt")
classifier = file_to_continuous_Bayesian_classifier("acceleration_speed_positions_continuous_Bayesian_classifier.txt")

# train_save_continuous_Bayesian_classifier(classifier, True, 1, 60)

test_continuous_Bayesian_classifier(classifier, True, 1, 1)

# predictions_continuous_Bayesian_classifier(classifier, True, 61, 100)
# Out:
# ----------------------------------------------------------------------
#
# Confusion Matrix 0:
#                        Predict label 0    Predict not label 0
#      Is label 0               76                   14
#    Isn't label 0              9                    97
#
# Accurary: 0.8826530612244898
# Precision: 0.8444444444444444
# Recall: 0.8941176470588236
# F1-score: 0.8685714285714287
#
# ----------------------------------------------------------------------
#
# Confusion Matrix 1:
#                        Predict label 1    Predict not label 1
#      Is label 1               33                   34
#    Isn't label 1              15                  114
#
# Accurary: 0.75
# Precision: 0.4925373134328358
# Recall: 0.6875
# F1-score: 0.5739130434782609
#
# ----------------------------------------------------------------------
#
# Confusion Matrix 2:
#                        Predict label 2    Predict not label 2
#      Is label 2               1                    2
# ...
